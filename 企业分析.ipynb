# %%
# %%html
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\a122861569\Desktop\com.csv")
data.head()
# Out:
#    bianh com_name com_addr   cat   se_cat  \
# 0      1     麦子金服       上海    金融       借贷
# 1      1     拓道金服       浙江    金融       借贷
# 2      1     云柏科技       广东  医疗健康  医疗器械及硬件
# 3      1     迷你生鲜       福建  电子商务     生鲜食品
# 4      1     一生健康       北京  医疗健康     寻医诊疗
#
#                                              com_des   born_data  death_data  \
# 0  麦子金服是一家移动互联网金融服务集团，为个人和企业提供包括财富管理、股权投资、投融资咨询等综...  2015-03-01  2019-11-25
# 1  拓道金服是一家专注于汽车抵押贷款这一细分市场的P2P互联网金融公司。拓道金服通过互联网民间的...  2013-11-01  2019-11-24
# 2  云柏科技是一家智能健康检测腕表研发商，专注于智能可穿戴设备领域。主要产品包括可穿戴式多功能云...  2014-09-01  2019-11-01
# 3  迷你生鲜是一家会员制水果生鲜电商网站，平台产品由基地直供，采购深入全国及东南亚各地区，减少中...  2017-11-01  2019-10-29
# 4  微爱康一款基于移动互联网的癌症患者互助型垂直社区产品，通过在线社会化问答和类轻博客交流模式，...  2015-01-01  2019-10-17
#
#    live_days financing  ...  death_reason       invest_name ceo_name ceo_des  \
# 0       1730        B轮  ...   政策监管 法律法规风险         海通开元&中缔资本      黄大容     董事长
# 1       2214        A轮  ...   政策监管 法律法规风险  蓝山中国资本&帮实资本&宏桥资本      张罗军     创始人
# 2       1887      尚未获投  ...          行业竞争               NaN      NaN     NaN
# 3        727      尚未获投  ...    现金流断裂 行业竞争               NaN      NaN     NaN
# 4       1750      尚未获投  ...   政策监管 法律法规风险               NaN      张耀斌     CEO
#
#                                          ceo_per_des Unnamed: 16  Unnamed: 17  \
# 0  黄大容，80后，经济学硕士，精通中英德三国语言。连续创业者，23岁创立第一家公司，25岁涉足...         NaN          NaN
# 1  杭州拓道科技有限公司执行董事兼总经理，重庆邮电学院计算机专业，创立杭州仁润科技有限公司，具有...         NaN          NaN
# 2                                                NaN         NaN          NaN
# 3                                                NaN         NaN          NaN
# 4                           张耀斌，为一生（北京）健康科技有限公司的创始人。         NaN          NaN
#
#    Unnamed: 18  Unnamed: 19  Unnamed: 20
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 21 columns]

# %%
province_mapping = {
    "上海": "上海市",
    "云南": "云南省",
    "内蒙古": "内蒙古自治区",
    "北京": "北京市",
    "台湾": "台湾省",
    "吉林": "吉林省",
    "四川": "四川省",
    "天津": "天津市",
    "宁夏": "宁夏回族自治区",
    "安徽": "安徽省",
    "山东": "山东省",
    "山西": "山西省",
    "广东": "广东省",
    "广西": "广西壮族自治区",
    "新疆": "新疆维吾尔自治区",
    "江苏": "江苏省",
    "江西": "江西省",
    "河北": "河北省",
    "河南": "河南省",
    "浙江": "浙江省",
    "海南": "海南省",
    "湖北": "湖北省",
    "湖南": "湖南省",
    "甘肃": "甘肃省",
    "福建": "福建省",
    "西藏": "西藏自治区",
    "贵州": "贵州省",
    "辽宁": "辽宁省",
    "重庆": "重庆市",
    "陕西": "陕西省",
    "青海": "青海省",
    "香港": "香港特别行政区",
    "黑龙江": "黑龙江省",
}

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
data['com_addr'] = data['com_addr'].str.strip()
data['com_addr'] = data['com_addr'].map(lambda x: province_mapping.get(x, x))
s = data.groupby('com_addr').size()
c=(
    Map()
    .add("倒闭企业数量",[*s.items()],"china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="地区分布"),
        visualmap_opts=opts.VisualMapOpts(max_=200),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="e53c690cfbe24282a42d473df8c9ac14" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_e53c690cfbe24282a42d473df8c9ac14 = echarts.init(
#                     document.getElementById('e53c690cfbe24282a42d473df8c9ac14'), 'white', {renderer: 'canvas'});
#                 var option_e53c690cfbe24282a42d473df8c9ac14 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5012\u95ed\u4f01\u4e1a\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 1034
#                 },
#                 {
#                     "name": "\u4e91\u5357\u7701",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u4e9a\u6d32",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4\u81ea\u6cbb\u533a",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 2239
#                 },
#                 {
#                     "name": "\u5317\u7f8e\u6d32",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u53f0\u6e7e\u7701",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5409\u6797\u7701",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u56db\u5ddd\u7701",
#                     "value": 282
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e02",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5b89\u5fbd\u7701",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u5c71\u4e1c\u7701",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u5c71\u897f\u7701",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c\u7701",
#                     "value": 1095
#                 },
#                 {
#                     "name": "\u5e7f\u897f\u58ee\u65cf\u81ea\u6cbb\u533a",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6b27\u6d32",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": 253
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u6cb3\u5317\u7701",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u6cb3\u5357\u7701",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": 395
#                 },
#                 {
#                     "name": "\u6d77\u5357\u7701",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u6e56\u5317\u7701",
#                     "value": 117
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u7518\u8083\u7701",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u798f\u5efa\u7701",
#                     "value": 140
#                 },
#                 {
#                     "name": "\u897f\u85cf\u81ea\u6cbb\u533a",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u8d35\u5dde\u7701",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u8fbd\u5b81\u7701",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u91cd\u5e86\u5e02",
#                     "value": 72
#                 },
#                 {
#                     "name": "\u9655\u897f\u7701",
#                     "value": 79
#                 },
#                 {
#                     "name": "\u9752\u6d77\u7701",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9999\u6e2f\u7279\u522b\u884c\u653f\u533a",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f\u7701",
#                     "value": 17
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5012\u95ed\u4f01\u4e1a\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u5012\u95ed\u4f01\u4e1a\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5730\u533a\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_e53c690cfbe24282a42d473df8c9ac14.setOption(option_e53c690cfbe24282a42d473df8c9ac14);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker
s = data.groupby('cat').size().sort_values(ascending=False)[:10].to_dict()
c=(
    Bar()
    .add_xaxis(list(s.keys()))
    .add_yaxis("倒闭企业数量",list(s.values()))
    .set_global_opts(title_opts=opts.TitleOpts(title="行业Top10"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="515483a38544440096971f98a876728b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_515483a38544440096971f98a876728b = echarts.init(
#                     document.getElementById('515483a38544440096971f98a876728b'), 'white', {renderer: 'canvas'});
#                 var option_515483a38544440096971f98a876728b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5012\u95ed\u4f01\u4e1a\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 925,
#                 789,
#                 595,
#                 510,
#                 500,
#                 421,
#                 376,
#                 374,
#                 334,
#                 311
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5012\u95ed\u4f01\u4e1a\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u5012\u95ed\u4f01\u4e1a\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7535\u5b50\u5546\u52a1",
#                 "\u4f01\u4e1a\u670d\u52a1",
#                 "\u672c\u5730\u751f\u6d3b",
#                 "\u91d1\u878d",
#                 "\u793e\u4ea4\u7f51\u7edc",
#                 "\u6587\u5a31\u4f20\u5a92",
#                 "\u6559\u80b2",
#                 "\u5de5\u5177\u8f6f\u4ef6",
#                 "\u6e38\u620f",
#                 "\u6c7d\u8f66\u4ea4\u901a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u884c\u4e1aTop10",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_515483a38544440096971f98a876728b.setOption(option_515483a38544440096971f98a876728b);
#         });
#     </script>

# %%
s = data.groupby('se_cat').size().sort_values(ascending=False)[:20].sort_values(ascending=True).to_dict()
c=(
    Bar()
    .add_xaxis(list(s.keys()))
    .add_yaxis("倒闭企业数量",list(s.values()))
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position="right"))
    .set_global_opts(title_opts=opts.TitleOpts(title="细分领域T20"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="64ff91a7788948589a29dfc12c48e86b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_64ff91a7788948589a29dfc12c48e86b = echarts.init(
#                     document.getElementById('64ff91a7788948589a29dfc12c48e86b'), 'white', {renderer: 'canvas'});
#                 var option_64ff91a7788948589a29dfc12c48e86b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5012\u95ed\u4f01\u4e1a\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 83,
#                 91,
#                 95,
#                 100,
#                 103,
#                 110,
#                 111,
#                 112,
#                 119,
#                 119,
#                 120,
#                 124,
#                 129,
#                 136,
#                 139,
#                 145,
#                 149,
#                 162,
#                 224,
#                 240
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5012\u95ed\u4f01\u4e1a\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u5012\u95ed\u4f01\u4e1a\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u513f\u7ae5\u65e9\u6559",
#                 "\u4e8b\u9879\u53ca\u6548\u7387",
#                 "\u5176\u4ed6\u7535\u5546\u670d\u52a1",
#                 "\u4ea4\u901a\u51fa\u884c",
#                 "\u6574\u5408\u8425\u9500\u4f20\u64ad",
#                 "\u7406\u8d22",
#                 "\u670d\u88c5\u670d\u9970",
#                 "\u5a92\u4f53\u53ca\u9605\u8bfb",
#                 "\u751f\u9c9c\u98df\u54c1",
#                 "\u964c\u751f\u4eba\u4ea4\u53cb",
#                 "\u5176\u4ed6\u4f01\u4e1a\u670d\u52a1",
#                 "\u672c\u5730\u7efc\u5408\u751f\u6d3b",
#                 "\u4eba\u529b\u8d44\u6e90",
#                 "\u7535\u5546\u89e3\u51b3\u65b9\u6848",
#                 "\u5174\u8da3\u793e\u533a",
#                 "\u884c\u4e1a\u4fe1\u606f\u5316\u53ca\u89e3\u51b3\u65b9\u6848",
#                 "\u501f\u8d37",
#                 "\u7f8e\u98df\u9910\u996e",
#                 "\u7efc\u5408\u7535\u5546",
#                 "\u6e38\u620f\u5f00\u53d1\u5546"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7ec6\u5206\u9886\u57dfT20",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_64ff91a7788948589a29dfc12c48e86b.setOption(option_64ff91a7788948589a29dfc12c48e86b);
#         });
#     </script>

# %%
data['born_year'] = data['born_data'].apply(lambda x: x[:4])
data['death_year'] = data['death_data'].apply(lambda x: x[:4])
s1 = data.groupby('born_year').size()
s2 = data.groupby('death_year').size()
s1 = pd.DataFrame({'year': s1.index, 'born': s1.values})
s2 = pd.DataFrame({'year': s2.index, 'death': s2.values})
s = pd.merge(s1,s2, on='year', suffixes=['born', 'death'])
s = s[s['year'] > '2008']

c = (
    Bar()
    .add_xaxis( s['year'].to_list())
    .add_yaxis("新生企业数量", s['born'].to_list())
    .add_yaxis("死亡企业数量", s['death'].to_list())
    .set_global_opts(title_opts=opts.TitleOpts(title="年份分布"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="272a5b39de99485f82fdb80732d0088d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_272a5b39de99485f82fdb80732d0088d = echarts.init(
#                     document.getElementById('272a5b39de99485f82fdb80732d0088d'), 'white', {renderer: 'canvas'});
#                 var option_272a5b39de99485f82fdb80732d0088d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u65b0\u751f\u4f01\u4e1a\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 164,
#                 268,
#                 583,
#                 940,
#                 1341,
#                 1410,
#                 944,
#                 252,
#                 34,
#                 6,
#                 1
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 25,
#                 40,
#                 57,
#                 70,
#                 182,
#                 335,
#                 1131,
#                 1458,
#                 2145,
#                 458,
#                 327
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u65b0\u751f\u4f01\u4e1a\u6570\u91cf",
#                 "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u65b0\u751f\u4f01\u4e1a\u6570\u91cf": true,
#                 "\u6b7b\u4ea1\u4f01\u4e1a\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2009",
#                 "2010",
#                 "2011",
#                 "2012",
#                 "2013",
#                 "2014",
#                 "2015",
#                 "2016",
#                 "2017",
#                 "2018",
#                 "2019"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5e74\u4efd\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_272a5b39de99485f82fdb80732d0088d.setOption(option_272a5b39de99485f82fdb80732d0088d);
#         });
#     </script>

# %%
def live_year(x):
    if x < 365:
        return '不到1年'
    if x < 365 * 2:
        return '1-2年'
    if x < 365 * 3:
        return '2-3年'
    if x < 365 * 4:
        return '3-4年'
    if x < 365 * 5:
        return '4-5年'
    if x < 365 * 10:
        return '5-10年'
    return '10年以上'

s = data.groupby(data['live_days'].apply(lambda x: live_year(x))).size()
from pyecharts import options as opts
from pyecharts.charts import Pie

c = (
    Pie()
    .add("", [*s.items()])
    .set_global_opts(title_opts=opts.TitleOpts(title="企业存活时长"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f3b2ecb15c6e4176af39eae0b77f9e58" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f3b2ecb15c6e4176af39eae0b77f9e58 = echarts.init(
#                     document.getElementById('f3b2ecb15c6e4176af39eae0b77f9e58'), 'white', {renderer: 'canvas'});
#                 var option_f3b2ecb15c6e4176af39eae0b77f9e58 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "1-2\u5e74",
#                     "value": 644
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a",
#                     "value": 60
#                 },
#                 {
#                     "name": "2-3\u5e74",
#                     "value": 2242
#                 },
#                 {
#                     "name": "3-4\u5e74",
#                     "value": 1108
#                 },
#                 {
#                     "name": "4-5\u5e74",
#                     "value": 954
#                 },
#                 {
#                     "name": "5-10\u5e74",
#                     "value": 1219
#                 },
#                 {
#                     "name": "\u4e0d\u52301\u5e74",
#                     "value": 45
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1-2\u5e74",
#                 "10\u5e74\u4ee5\u4e0a",
#                 "2-3\u5e74",
#                 "3-4\u5e74",
#                 "4-5\u5e74",
#                 "5-10\u5e74",
#                 "\u4e0d\u52301\u5e74"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u4f01\u4e1a\u5b58\u6d3b\u65f6\u957f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f3b2ecb15c6e4176af39eae0b77f9e58.setOption(option_f3b2ecb15c6e4176af39eae0b77f9e58);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

invest = {}
for row in data['invest_name'].values:
    if not pd.isnull(row):
        for name in row.split('&'):
            invest[name] = invest.get(name, 0) + 1
invest = [*invest.items()]
invest.sort(key=lambda x: x[1], reverse=True)
c = (
    WordCloud()
    .add("", invest[:150], word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="投资人词云"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="1523867267e64fddac176f7a56965f68" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_1523867267e64fddac176f7a56965f68 = echarts.init(
#                     document.getElementById('1523867267e64fddac176f7a56965f68'), 'white', {renderer: 'canvas'});
#                 var option_1523867267e64fddac176f7a56965f68 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u5929\u4f7f\u6e7e",
#                     "value": 32,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,15,84)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u771f\u683c\u57fa\u91d1",
#                     "value": 30,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,42,118)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9669\u5cf0\u957f\u9752",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(79,59,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "IDG\u8d44\u672c",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(129,159,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u521b\u65b0\u5de5\u573a",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,4,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ecf\u7eac\u4e2d\u56fd",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,138,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ea2\u6749\u8d44\u672c\u4e2d\u56fd",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(135,129,63)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "PreAngel",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,142,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6885\u82b1\u521b\u6295",
#                     "value": 16,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,140,72)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6668\u5174\u8d44\u672c",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(65,30,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e5d\u5408\u521b\u6295",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(21,15,119)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5947\u864e360",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,29,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9752\u677e\u57fa\u91d1",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,126,152)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6d2a\u6cf0\u57fa\u91d1",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(79,60,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6208\u58c1\u521b\u6295",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(51,122,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5fb7\u6c83\u57fa\u91d1",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,29,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u817e\u8baf",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(151,113,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u82f1\u8bfa\u5929\u4f7f\u57fa\u91d1",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,124,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5fb7\u8fc5\u6295\u8d44",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,63,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b56\u6e90\u521b\u6295",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,115,59)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u521b\u4e1a\u63a5\u529b\u5929\u4f7f",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,114,72)"
#                         }
#                     }
#                 },
#                 {

# %%
death_reason = {}
for row in data['death_reason'].values:
    if not pd.isnull(row):
        for name in row.split(' '):
            death_reason[name] = death_reason.get(name, 0) + 1
c = (
    WordCloud()
    .add("", [*death_reason.items()], word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="倒闭原因词云"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="de67b82746b94a67bd6ba49ce9a7cc70" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_de67b82746b94a67bd6ba49ce9a7cc70 = echarts.init(
#                     document.getElementById('de67b82746b94a67bd6ba49ce9a7cc70'), 'white', {renderer: 'canvas'});
#                 var option_de67b82746b94a67bd6ba49ce9a7cc70 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u653f\u7b56\u76d1\u7ba1",
#                     "value": 88,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(14,81,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cd5\u5f8b\u6cd5\u89c4\u98ce\u9669",
#                     "value": 65,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,151,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u884c\u4e1a\u7ade\u4e89",
#                     "value": 354,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,119,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73b0\u91d1\u6d41\u65ad\u88c2",
#                     "value": 116,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(118,8,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5546\u4e1a\u6a21\u5f0f\u532e\u4e4f",
#                     "value": 469,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,51,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u70e7\u94b1",
#                     "value": 83,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,6,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e1a\u52a1\u8c03\u6574",
#                     "value": 141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,137,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e02\u573a\u4f2a\u9700\u6c42",
#                     "value": 217,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,81,42)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u5165\u573a\u65f6\u673a",
#                     "value": 113,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,91,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u878d\u8d44\u80fd\u529b\u4e0d\u8db3",
#                     "value": 107,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(134,93,85)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u7f3a\u9677\u4e25\u91cd",
#                     "value": 31,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(47,32,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e1a\u52a1\u8fc7\u4e8e\u5206\u6563",
#                     "value": 63,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,157,28)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b9a\u4ef7/\u6210\u672c\u95ee\u9898",
#                     "value": 59,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(50,48,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8425\u9500\u4e0d\u8db3",
#                     "value": 44,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,42,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u521b\u59cb\u4eba\u95ee\u9898",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,149,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8f6c\u578b\u95ee\u9898",
#                     "value": 39,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(21,54,61)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56e2\u961f\u80fd\u529b\u4e0d\u8db3",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,138,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0e\u6295\u8d44\u4eba\u51b2\u7a81",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,90,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56e2\u961f\u7f3a\u4e4f\u6fc0\u60c5",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(153,104,150)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u91cd\u89c6\u5ba2\u6237",
#                     "value": 11,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,91,124)"
#                         }
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [

# %%
import jieba
ceo_per_des = {}
for row in data['ceo_per_des'].values:
    if not pd.isnull(row):
        result = jieba.lcut(row)
        for name in result:
            if len(name) == 1:
                break
            ceo_per_des[name] = ceo_per_des.get(name, 0) + 1
ceo_per_des = [*ceo_per_des.items()]
ceo_per_des.sort(key=lambda x: x[1], reverse=True)
c = (
    WordCloud()
    .add("", ceo_per_des[:100], word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="ceo描述词云"))
)
c.render_notebook()
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\A12286~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.494 seconds.
# Prefix dict has been built successfully.
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="dfcfe4ae8fb14f398933e1ef6839eb33" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_dfcfe4ae8fb14f398933e1ef6839eb33 = echarts.init(
#                     document.getElementById('dfcfe4ae8fb14f398933e1ef6839eb33'), 'white', {renderer: 'canvas'});
#                 var option_dfcfe4ae8fb14f398933e1ef6839eb33 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u6709\u9650\u516c\u53f8",
#                     "value": 245,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,139,108)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u79d1\u6280",
#                     "value": 125,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,52,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6267\u884c",
#                     "value": 100,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,34,126)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8463\u4e8b",
#                     "value": 100,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,18,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u521b\u59cb\u4eba",
#                     "value": 95,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,56,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "CEO",
#                     "value": 86,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,26,106)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 72,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,85,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 51,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(151,130,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7edc\u79d1\u6280",
#                     "value": 41,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,144,22)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5733\u5e02",
#                     "value": 30,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,149,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": 25,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,66,41)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8463\u4e8b\u957f",
#                     "value": 25,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,59,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": 24,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,71,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fe1\u606f",
#                     "value": 22,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,70,104)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u53f8",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,142,112)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6295\u8d44",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,34,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,127,72)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7edc",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,40,103)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd5\u4e1a",
#                     "value": 14,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,119,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 14,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(27,83,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ba1\u7406",
#                     "value": 14,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,9,141)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u9650\u8d23\u4efb",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "colo
